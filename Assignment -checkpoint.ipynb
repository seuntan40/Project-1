# %% [markdown]
# ### Importation of  Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# ### Data Importation

# %%
pd.read_csv(r"C:\Users\USER\Desktop\Salaries.csv



pd.read_csv(r"C:\Users\USER\Desktop\Billionaires Statistics Dataset - Billionaires Statistics Dataset new.csv"
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
data = pd.read_csv(r"C:\Users\USER\Desktop\Salaries.csv")

# %%
data
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
4. Display All the Employee Names from Fire Department
5. Find The Minimum,Maximum and Average BasePay
6. Replace 'Not provided' in EmployeeName Column to Nan
7. Drop The Rows Having 5 Missing Values
8. Find The Job Title Of ALBERT PARDINI
9. How Much ALBERT PARDINI makes(include Benefits)
10. Display Name Of The Person Having The Highest Basepay
11. Find The average Basepay of all Employees per Year
12. Find Average Basepay Of All Employee Per Job Title
13. Find The Average Basepay of All Employee Having job Title Accountant
14. Five Most Common Job

# %%
### 1. Find The Occurence Of the Employee Names(Top5)

# %%
data["EmployeeName"].unique()

# %%
data['EmployeeName'].value_counts().head(5)

# %% [markdown]
# ### 2. Find The Number Of Unique Jobs Titles

# %%
data["JobTitle"].unique()

# %%
unique_job_titles_count = data['JobTitle'].nunique()
print("Number of unique job titles:", unique_job_titles_count)

# %% [markdown]
# ### 3. Total Number Of Job Titles Contain captain

# %%
 data['JobTitle'].str.contains('CAPTAIN', case=False, na=False).sum()
print("Total Number Of Job Titles Contain captain:", data['JobTitle'].str.contains('CAPTAIN', case=False, na=False).sum())

# %%
### Display All the Employee Names from Fire Department

# %%
print(data.columns)
print(data['JobTitle'].unique())

# %%
data. index[2]

# %%
# Filter the data to get only employees with the job title 'Fire Department'
fire_department_employees = data[data['JobTitle'] == 'Fire Department']

# Display only the employee names
employee_names = fire_department_employees['EmployeeName']
print("Employees in the Fire Department:")
print(employee_names)

# %%
import pandas as pd

# Count occurrences of each employee name
name_counts = data['EmployeeName'].value_counts()

# Get the top 5 most common employee names
top_5_names = name_counts.head(5)

print("Top 5 Employee Names by Occurrence:")
print(top_5_names)

# %%
# Find the number of unique job titles
unique_job_titles_count = data['JobTitle'].nunique()

print("Number of unique job titles:", unique_job_titles_count)

# %%
# Find the number of unique job titles
unique_job_titles_count = data['JobTitle'].nunique()

print("Number of unique job titles:", unique_job_titles_count)
